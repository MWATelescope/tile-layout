# %%
import math
import time
WIDTH = 1024
HEIGHT = 768
import juplot
juplot.init(width=WIDTH, height=HEIGHT)
# Out:
# <div id="glowscript" class="glowscript"></div>
# <div id="glowscript" class="glowscript"></div>

# %%
#TILEFILE = 'config-compact.txt'   # Hex configuration for Q3 2016 onwards
#PADFILE = 'pads-verycompact.txt'

#TILEFILE = 'config-current.txt'
#PADFILE = 'pads-current.txt'

TILEFILE = 'config-longbaseline.txt'   # Long-baseline Phase 2 configuration
PADFILE = 'pads-longbaseline.txt'

OUTFILE = 'topt-run.txt'
CSVFILE = 'topt-run.csv'

#KEEPCURRENT = True

KEEPCURRENT = False   # Don't use KEEPCURRENT=True for long baselines, becuase it would leave the
                      # new LB tiles connected to receivers in the core, with fibres that are too long.

LIGHTNING = []
BADLIGHTNING = []

FLENGTHS = [90, 150, 230, 320, 400, 524]
FLAVORS = {90:'RG6_90', 150:'RG6_150', 230:'RG6_230', 320:'LMR400_320', 400:'LMR400_400', 524:'LMR400_524'}

LMULT = 1.00   # Multiply line-of-sight lengths by this, to determine actual cable length
LADD = 10.0    # Add this length (in metres) to scaled line-of-sight length to determine actual cable length

DELAY = 0.0001

# %%
TILES = []
PADS = []
TDICT = {}
PDICT = {}
LMATRIX = {}
CONNECTED = []
FNAMES = [FLAVORS[length] for length in FLENGTHS]

# %%
class Pad(object):
  """Represents a single receiver pad, which can handle up to 8 inputs from tiles.
  """
  def __init__(self, name='', east=0.0, north=0.0, enabled=False):
    self.name = name
    self.east = east
    self.north = north
    self.enabled = enabled
    self.inputs = {}   # Dict with tile name as key, and tuples of (tileobject,cablelength,flavor) as value.

  def __repr__(self):
    if self.enabled:
      s = "%s:\n  " % self.name + '\n  '.join(["%7s with %s (%2.0f m LoS)" % (tname, tdata[2], tdata[1]) for tname,tdata in self.inputs.items()]) + "\n"
      mindist, maxdist = 9e99, 0.0
      for tname, tdata in self.inputs.items():
        if tdata[1] < mindist:
          mindist = tdata[1]
        if tdata[1] > maxdist:
          maxdist = tdata[1]
      s += "  Max = %2.1f, Min = %2.1f, difference = %2.1f\n" % (maxdist, mindist, maxdist - mindist)
      return s
    else:
      return "%s: Disabled\n" % self.name

  def maxlen(self):
    """Returns the maximum cable length for any connected tile.
    """
    maxl = ('',0.0)
    for tname, tdata in self.inputs.items():
      if tdata[1] > maxl[1]:
        maxl = (tname, tdata[1])
    return maxl

  def minlen(self):
    """Returns the minimum cable length for any connected tile.
    """
    minl = ('',9e99)
    for tname, tdata in self.inputs.items():
      if tdata[1] < minl[1]:
        minl = (tname, tdata[1])
    return minl

  def maxdiff(self):
    return self.maxlen() - self.minlen()

  def freeslot(self):
    """Returns true if there is a free input.
    """
    if 'DP' in self.name.upper():
      return True
    else:
      return len(self.inputs) < 8

  def addtile(self, tileobj, fixlength=None, manual=True, color=None):
    """Add the given tile object to the input list.

       If fixlength is given (in metres), use that as the cable length instead of
       the straight-line distance between tile and pad (for manually forcing
       connections).

       If manual is True (the default), or if a fixed length is supplied,
       indicate by arrow color that the connection has
       been manually chosen, not automatically picked by the algorithm.
    """
    if not self.freeslot():
      print("No free slots in pad %s for tile %s" % (self.name, tileobj.name))
      return False

    if tileobj.name in self.inputs:
      print("Tile %s already connected to pad %s" % (tileobj.name, self.name))
      return False

    if tileobj.name in CONNECTED:
      print("Tile %s already connected to a different pad" % (tileobj.name,))
      return False

    if fixlength is not None:
      clen = fixlength
    else:
      clen = LMATRIX[self.name][tileobj.name]

    flavor = None
    for len in FLENGTHS:
      if (clen * LMULT) + LADD < len:
        flavor = FLAVORS[len]
        break
    if flavor is None:
      flavor = 'FIBRE'

    oldlink = False
    if tileobj.name.startswith('Tile') or tileobj.name[0].isdigit():
      tnum = int(''.join([c for c in tileobj.name if c.isdigit()]))
      rnum, slotnum = divmod(tnum,10)
      oldpad = PDICT['Rx%d' % rnum]
      if (oldpad.east == self.east) and (oldpad.north == self.north):
        oldlink = True

    if color is None and oldlink:
      color = juplot.v(1.0, 1.0, 0.0)

    self.inputs[tileobj.name] = (tileobj, clen, flavor)
    CONNECTED.append(tileobj.name)
    print("Connected tile %s to pad %s with cable %s (LoS=%5.1f m)" % (tileobj.name, self.name, flavor, clen))
    if manual or (fixlength is not None):
      juplot.update(pad=self, tname=tileobj.name, fixed=True, color=color)
    else:
      juplot.update(pad=self, tname=tileobj.name, fixed=False, color=color)
    time.sleep(DELAY)
    return True

  def findclosest(self):
    """Loop over all unconnected tiles and return the closest one to this receiver
    """
    mindist = 9e99
    mintile = None
    for tileobj in TILES:
      clen = LMATRIX[self.name][tileobj.name]
      if (clen < mindist) and tileobj.name not in CONNECTED:
        mindist = clen
        mintile = tileobj
    return mintile

# %%
class Tile(object):
  """Represents a single tile.
  """
  def __init__(self, name='', east=0.0, north=0.0):
    self.name = name
    self.east = east
    self.north = north

# %%
def bestinput(tileobj):
  """Given a tile object, find the closest pad with a free input, and return pad object and distance as a tuple.
  """
  mindist = 9e99
  minpad = None
  for pad in PADS:
    clen = LMATRIX[pad.name][tileobj.name]
    if (clen < mindist) and pad.enabled and pad.freeslot():
      mindist = clen
      minpad = pad
  return (minpad,mindist)

# %%
def findlongest():
  """Loop over all tiles, and find the one that has the _longest_ distance to its _closest_ receiver.

     The 'connected' argument contains a list of all tile names that have already been connected to pads.
  """
  maxlen = 0.0
  maxtile = None
  maxtilepad = None
  for tileobj in TILES:
    if tileobj.name not in CONNECTED:
      pad, dist = bestinput(tileobj)
      if dist > maxlen:
        maxlen = dist
        maxtile = tileobj
        maxtilepad = pad
  return maxtile, maxlen, maxtilepad

# %%
def connectall():
  """Connect all tiles, going from longest cables to shortest.
  """
  connected = []
  while True:
    maxtile, maxlen, maxtilepad = findlongest()
    if maxtile is None:
      break
    maxtilepad.addtile(maxtile, manual=False)

  print("All tiles connected")
  prstats()
  while True:
    juplot.vpython.rate(2)

# %%
def load():
  global TILES, PADS, LMATRIX, PDICT, TDICT
  flines = file(TILEFILE, 'r').readlines()
  for line in flines:
    tname, teast, tnorth = line.split(',')[:3]
    tile = Tile(name=tname, east=float(teast), north=float(tnorth))
    TILES.append(tile)
    TDICT[tname] = tile

  flines = file(PADFILE, 'r').readlines()
  for line in flines:
    pname, peast, pnorth, penabled = line.split(',')
    pad = Pad(name=pname, east=float(peast), north=float(pnorth), enabled=int(penabled))
    PADS.append(pad)
    PDICT[pname] = pad

  for tile in TILES:
    for pad in PADS:
      clen = math.sqrt( (tile.east - pad.east)**2 + (tile.north - pad.north)**2)
      if pad.name not in LMATRIX:
        LMATRIX[pad.name] = {}
      LMATRIX[pad.name][tile.name] = clen

# %%
def plot(forever=True):
  juplot.plot(tiles=TILES, pads=PADS)
  if forever:
    while True:
      juplot.vpython.rate(2)

# %%
def prstats():
  ftotal = 0.0
  ctotal = 0.0
  newtotal = 0.0
  flinks = 0
  rflinks = 0
  oldlinkstotal = 0
  fhist = {}
  ofhist = {}
  for flavor in FNAMES:
    fhist[flavor] = 0
    ofhist[flavor] = 0
  fibrelist = []
  outf = open(OUTFILE, 'w')
  csvf = open(CSVFILE, 'w')
  header = "Tile optimisation run at %s\nTiles=%s, pad configuration=%s\n\n" % (time.ctime(), TILEFILE, PADFILE)
  print(header)
  outf.write(header)
  csvf.write('# Run at %s, Tiles=%s, Pads=%s\n' % (time.ctime(), TILEFILE, PADFILE))
  for pad in PADS:
    if pad.enabled:
      print(pad)
      outf.write(str(pad))
      cpad = 0.0
      fpad = 0.0
      newlen = 0.0
      oldlinks = 0
      for tname, tdata in pad.inputs.items():
        tileobj, clen, flavor = tdata
        if flavor == 'FIBRE':
          fibrelist.append(clen)   # Add a fibre of this length to the list
        else:
          fhist[flavor] += 1    # One more cable of this flavor
        if clen <= 525 and 'RX' in pad.name.upper():
          cpad += clen
        else:
          fpad += clen
          flinks += 1
        if tname.startswith('Tile') or tname[0].isdigit():
          tnum = int(''.join([c for c in tname if c.isdigit()]))
          rnum,slotnum = divmod(tnum,10)
          oldpad = PDICT['Rx%d' % rnum]
          if (oldpad.east == pad.east) and (oldpad.north == pad.north):
            oldlinks += 1
            ofhist[flavor] += 1
          else:
            csvf.write('%s, %5.1f, %s\n' % (tileobj.name, clen, flavor))
            newlen += clen
        else:
          csvf.write('%s, %5.1f, %s\n' % (tileobj.name, clen, flavor))
          newlen += clen

      print("  LoS length totals: %4.3f km of copper, %4.3f km of fibre" % (cpad/1000, fpad/1000))
      outf.write("  LoS length totals: %4.3f km of copper, %4.3f km of fibre\n" % (cpad/1000, fpad/1000))
#      clen = pad.maxlen()[1]
#      if clen <= 525 and 'RX' in pad.name.upper():
#        croundtotal += clen*8
#        print "  Equal length cables totals: %4.3f km of COPPER." % (clen*8/1000,)
#      else:
#        froundtotal += clen*8
#        rflinks += 8
#        print "  Equal length cables totals: %4.3f km of FIBRE." % (clen*8/1000,)
      ctotal += cpad
      ftotal += fpad
      newtotal += newlen
      oldlinkstotal += oldlinks
      if 'RX' in pad.name.upper():
        print("  %d existing cables re-used, plus ~%4.3f km of new cable\n" % (oldlinks, newlen/1000))
        outf.write("  %d existing cables re-used, plus ~%4.3f km of new cable\n\n" % (oldlinks, newlen/1000))
      else:
        trlen = math.sqrt(pad.east*pad.east + pad.north*pad.north)
        print("  Trunk length to core is %4.3fkm long, %d tiles wide\n" % (trlen/1000, len(pad.inputs.keys())))
        outf.write("  Trunk length to core is %4.3fkm long, %d tiles wide\n\n" % (trlen/1000, len(pad.inputs.keys())))
        cabplot.trunk(pad)

  summary = '\n'
  summary += "Totals for the whole array:\n"
  summary += "   LoS lengths: %4.3f km of COPPER, %4.3f km of FIBRE\n" % (ctotal/1000, ftotal/1000)
  summary += "   %d existing tile connections re-used, %4.3f km new copper\n" % (oldlinkstotal, newtotal/1000)
  for flavor in FNAMES:
    summary += "  Cable %s: %d lengths in total, %d of them are re-used.\n" % (flavor, fhist[flavor], ofhist[flavor])
  fibrelist.sort()
  summary += "  Fibre: %d lengths, with Line of Sight (LOS) distances:\n    %s\n" % (len(fibrelist), fibrelist)
  print(summary)
  outf.write(summary)
  outf.close()
  csvf.close()

# %%
load()

# %%
plot(forever=False)

# %%
if (TILEFILE == 'config1.txt') and ('pads-compact' in PADFILE):   # Any case with a compact configuration and receivers moved in
  print("Force Rx12, Rx13, Rx14 to be connected to the East hexagon (leaving four copper tiles on that hexagon).")

  pad = PDICT['Rx12']
  for tname in ['HN29', 'HN33', 'HN35', 'HN31', 'HN13', 'HN17', 'HN15', 'HN27', ]:
    pad.addtile(TDICT[tname])
  pad = PDICT['Rx13']
  for tname in ['HN09', 'HN03', 'HN05', 'HN11', 'HN23', 'HN02', 'HN08', 'HN20', ]:
    pad.addtile(TDICT[tname])
  pad = PDICT['Rx14']
  for tname in ['HN04', 'HN06', 'HN12', 'HN24', 'HN18', 'HN16', 'HN28', 'HN32', ]:
    pad.addtile(TDICT[tname])
  pad = PDICT['Rx16']
  for tname in ['HN19', 'HN22', 'HN26', 'HN30', 'HN07', 'HN10', 'HN14', 'HN34', ]:
    pad.addtile(TDICT[tname])

elif ( (TILEFILE == 'config-longbaseline.txt') and
       (PADFILE == 'pads-longbaseline.txt') ):   # Extended configuration with Rx16 left on original pad
  print("Force longer cables and Rx10/Rx16 for the 8 tiles on the far side of the airstrip")
  pad = PDICT['Rx10']
  for tname in ['LB_SW1', 'LB_SW2', 'LB_SW3', 'LB_SW4', 'LB_SW5', 'LB_SW6', 'LB_SW7', 'LB_SW8']:
    pad.addtile(TDICT[tname], fixlength=2650.0)

elif (TILEFILE == 'config1.txt') and (PADFILE == 'pads-verycompact.txt'):
  pad = PDICT['Rx8a']
  for tname in ['HN29', 'HN33', 'HN25', 'HN13', 'HN21', 'HN09', 'HN03', 'HN19']:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx9a']
  for tname in ['HN35', 'HN31', 'HN17', 'HN15', 'HN27', 'HN05', 'HN11', 'HN23']:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx1a']
  for tname in ['HN07', 'HN01', 'HN22', 'HN10', 'HN04', 'HN26', 'HN14', 'HN18']:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx2a']
  for tname in ['HN30', 'HN34', 'HN36', 'HN06', 'HN16', 'HN32', 'HE19', 'HE22']:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx3a']
  for tname in ['HE35', 'HE31']:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx4a']
  for tname in ['HE15', 'HE27', 'HE33', 'HE17', 'HE11', 'HE23', 'HE29', 'HE20']:
    pad.addtile(TDICT[tname])

# Final layout for new hex positions and very compact receiver positions
elif (TILEFILE == 'config-compact.txt') and (PADFILE == 'pads-verycompact.txt'):
  pad = PDICT['Rx9a']
  for tname in ['EastHex%d' % i for i in [1,2,3,4, 5,6,7,8]]:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx3']
  for tname in ['EastHex%d' % i for i in [9,10,11,12, 13,14,15,16]]:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx3a']
  for tname in ['EastHex%d' % i for i in [17,18,19,20, 21,22,23,24]]:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx4']
  for tname in ['EastHex%d' % i for i in [25,26,27,28, 29,30,31,32]]:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx4a']
  for tname in (['EastHex%d' % i for i in [33,34,35,36]] +
                ['SouthHex%d' % i for i in [1,2,3,4]]):
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx5']
  for tname in ['SouthHex%d' % i for i in [5,6,7,8, 9,10,11,12]]:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx5a']
  for tname in ['SouthHex%d' % i for i in [13,14,15,16, 17,18,19,20]]:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx6']
  for tname in ['SouthHex%d' % i for i in [21,22,23,24, 25,26,27,28]]:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx6a']
  for tname in ['SouthHex%d' % i for i in [29,30,31,32, 33,34,35,36]]:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx1a']
  for tname in ['%d' % i for i in [61,62,63,64, 65,66,67,68]]:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx2a']
  for tname in ['%d' % i for i in [31,32,33,34, 35,36,37,38]]:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx1']
  for tname in ['%d' % i for i in [11,12,13,14, 15,16,17,18]]:
    pad.addtile(TDICT[tname])

  pad = PDICT['Rx2']
  for tname in ['%d' % i for i in [27,41,42,43, 44,45,46,48]]:
    pad.addtile(TDICT[tname])
# Out:
# Force longer cables and Rx10/Rx16 for the 8 tiles on the far side of the airstrip
# Connected tile LB_SW1 to pad Rx10 with cable FIBRE (LoS=2650.0 m)
# Connected tile LB_SW2 to pad Rx10 with cable FIBRE (LoS=2650.0 m)
# Connected tile LB_SW3 to pad Rx10 with cable FIBRE (LoS=2650.0 m)
# Connected tile LB_SW4 to pad Rx10 with cable FIBRE (LoS=2650.0 m)
# Connected tile LB_SW5 to pad Rx10 with cable FIBRE (LoS=2650.0 m)
# Connected tile LB_SW6 to pad Rx10 with cable FIBRE (LoS=2650.0 m)
# Connected tile LB_SW7 to pad Rx10 with cable FIBRE (LoS=2650.0 m)
# Connected tile LB_SW8 to pad Rx10 with cable FIBRE (LoS=2650.0 m)

# %%
  if KEEPCURRENT:    # Force existing tiles to connect to the receivers they are connected to now, if possible
    for tname,tile in TDICT.items():
      if tname.startswith('Tile') or tname[0].isdigit():
        tnum = int(''.join([c for c in tname if c.isdigit()]))
        rnum,slotnum = divmod(tnum,10)
        pname = 'Rx%d' % rnum
        if PDICT[pname].enabled and PDICT[pname].freeslot():
          tid = tnum
          if tid in BADLIGHTNING:
            ccolor = juplot.v(1.0,0.0,0.0)
            print("%s:d bad ligtning" % (pname, tid))
          elif tid in LIGHTNING:
            ccolor = (1.0,0.3,0.0)
            print("%s:%d lightning" % (pname, tid))
#          elif len(BADLIGHTNING):
#            ccolor = juplot.v(1.0,1.0,1.0)
          else:
            ccolor = juplot.v(1.0, 1.0, 0.0)
          PDICT[pname].addtile(tile, color=ccolor)
        else:
          oldpad = PDICT[pname]
          for newpad in PADS:
            if (oldpad.east == newpad.east) and (oldpad.north == newpad.north) and (newpad.enabled) and (newpad.freeslot()):
              newpad.addtile(tile)

# %%
connectall()
# Out:
# Connected tile LB_NE4 to pad Rx12 with cable FIBRE (LoS=2859.1 m)
# Connected tile LB_NE3 to pad Rx12 with cable FIBRE (LoS=2676.8 m)
# Connected tile LB_E4 to pad Rx14 with cable FIBRE (LoS=2633.6 m)
# Connected tile LB_NE5 to pad Rx12 with cable FIBRE (LoS=2578.3 m)
# Connected tile LB_SE8 to pad Rx14 with cable FIBRE (LoS=2378.4 m)
# Connected tile LB_NE2 to pad Rx12 with cable FIBRE (LoS=2368.1 m)
# Connected tile LB_NE6 to pad Rx12 with cable FIBRE (LoS=2301.5 m)
# Connected tile LB_NE8 to pad Rx12 with cable FIBRE (LoS=2234.2 m)
# Connected tile LB_E5 to pad Rx14 with cable FIBRE (LoS=2223.1 m)
# Connected tile LB_E6 to pad Rx14 with cable FIBRE (LoS=2049.9 m)
# Connected tile LB_NE7 to pad Rx12 with cable FIBRE (LoS=2038.7 m)
# Connected tile LB_E3 to pad Rx14 with cable FIBRE (LoS=1973.4 m)
# Connected tile LB_N2 to pad Rx12 with cable FIBRE (LoS=1866.1 m)
# Connected tile LB_N4 to pad Rx9 with cable FIBRE (LoS=2517.6 m)
# Connected tile LB_NNE3 to pad Rx9 with cable FIBRE (LoS=2455.1 m)
# Connected tile LB_NNE4 to pad Rx9 with cable FIBRE (LoS=2397.3 m)
# Connected tile LB_NE1 to pad Rx14 with cable FIBRE (LoS=2341.8 m)
# Connected tile LB_N3 to pad Rx8 with cable FIBRE (LoS=2285.7 m)
# Connected tile LB_N1 to pad Rx8 with cable FIBRE (LoS=2215.0 m)
# Connected tile LB_N5 to pad Rx9 with cable FIBRE (LoS=2040.2 m)
# Connected tile LB_NNE8 to pad Rx9 with cable FIBRE (LoS=1965.5 m)
# Connected tile LB_NNE2 to pad Rx9 with cable FIBRE (LoS=1957.7 m)
# Connected tile LB_NNE5 to pad Rx14 with cable FIBRE (LoS=1864.4 m)
# Connected tile LB_E2 to pad Rx14 with cable FIBRE (LoS=1853.6 m)
# Connected tile LB_SE4 to pad Rx5 with cable FIBRE (LoS=2446.1 m)
# Connected tile LB_ESE3 to pad Rx9 with cable FIBRE (LoS=2347.5 m)
# Connected tile LB_SE7 to pad Rx5 with cable FIBRE (LoS=2331.3 m)
# Connected tile LB_ESE7 to pad Rx9 with cable FIBRE (LoS=2289.9 m)
# Connected tile LB_ESE5 to pad Rx9a with cable FIBRE (LoS=2280.3 m)
# Connected tile LB_SE2 to pad Rx5 with cable FIBRE (LoS=2279.4 m)
# Connected tile LB_ESE2 to pad Rx9a with cable FIBRE (LoS=2175.1 m)
# Connected tile LB_E7 to pad Rx9a with cable FIBRE (LoS=2154.7 m)
# Connected tile LB_ESE8 to pad Rx3 with cable FIBRE (LoS=1941.5 m)
# Connected tile LB_E8 to pad Rx9a with cable FIBRE (LoS=1927.9 m)
# Connected tile LB_ESE4 to pad Rx9a with cable FIBRE (LoS=1860.8 m)
# Connected tile LB_ESE6 to pad Rx9a with cable FIBRE (LoS=1782.0 m)
# Connected tile LB_N7 to pad Rx8 with cable FIBRE (LoS=1771.4 m)
# Connected tile LB_SE5 to pad Rx5 with cable FIBRE (LoS=1766.9 m)
# Connected tile LB_SE3 to pad Rx5 with cable FIBRE (LoS=1755.0 m)
# Connected tile LB_SE6 to pad Rx5 with cable FIBRE (LoS=1713.2 m)
# Connected tile LB_N8 to pad Rx8 with cable FIBRE (LoS=1636.7 m)
# Connected tile LB_E1 to pad Rx9a with cable FIBRE (LoS=1630.6 m)
# Connected tile LB_N6 to pad Rx9a with cable FIBRE (LoS=1619.0 m)
# Connected tile LB_NNE7 to pad Rx8 with cable FIBRE (LoS=1693.4 m)
# Connected tile LB_NNE6 to pad Rx3 with cable FIBRE (LoS=1665.1 m)
# Connected tile LB_ESE1 to pad Rx3 with cable FIBRE (LoS=1509.3 m)
# Connected tile LB_SE1 to pad Rx5 with cable FIBRE (LoS=1454.9 m)
# Connected tile Tile142 to pad Rx3 with cable FIBRE (LoS=1370.7 m)
# Connected tile Tile151 to pad Rx5 with cable FIBRE (LoS=1368.8 m)
# Connected tile Tile121 to pad Rx8 with cable FIBRE (LoS=1360.5 m)
# Connected tile Tile133 to pad Rx3 with cable FIBRE (LoS=1339.6 m)
# Connected tile Tile132 to pad Rx3 with cable FIBRE (LoS=1320.5 m)
# Connected tile LB_NNE1 to pad Rx8 with cable FIBRE (LoS=1271.7 m)
# Connected tile Tile111 to pad Rx8 with cable FIBRE (LoS=1238.6 m)
# Connected tile Tile128 to pad Rx1 with cable FIBRE (LoS=1165.7 m)
# Connected tile Tile131 to pad Rx3 with cable FIBRE (LoS=1118.8 m)
# Connected tile Tile118 to pad Rx1 with cable FIBRE (LoS=1094.3 m)
# Connected tile Tile141 to pad Rx3 with cable FIBRE (LoS=1092.8 m)
# Connected tile Tile164 to pad Rx6 with cable FIBRE (LoS=1089.2 m)
# Connected tile Tile152 to pad Rx6 with cable FIBRE (LoS=1086.5 m)
# Connected tile Tile163 to pad Rx6 with cable FIBRE (LoS=1007.3 m)
# Connected tile Tile165 to pad Rx6 with cable FIBRE (LoS=950.5 m)
# Connected tile Tile107 to pad Rx1 with cable FIBRE (LoS=921.3 m)
# Connected tile Tile108 to pad Rx1 with cable FIBRE (LoS=908.0 m)
# Connected tile Tile127 to pad Rx3a with cable FIBRE (LoS=712.1 m)
# Connected tile Tile143 to pad Rx6 with cable FIBRE (LoS=698.7 m)
# Connected tile Tile166 to pad Rx6 with cable FIBRE (LoS=647.9 m)
# Connected tile Tile112 to pad Rx1 with cable FIBRE (LoS=640.7 m)
# Connected tile Tile114 to pad Rx1 with cable FIBRE (LoS=637.8 m)
# Connected tile Tile146 to pad Rx3a with cable FIBRE (LoS=626.5 m)
# Connected tile Tile124 to pad Rx3a with cable FIBRE (LoS=620.4 m)
# Connected tile Tile153 to pad Rx6 with cable FIBRE (LoS=617.8 m)
# Connected tile Tile161 to pad Rx6 with cable FIBRE (LoS=612.2 m)
# Connected tile Tile167 to pad Rx6a with cable FIBRE (LoS=611.1 m)
# Connected tile Tile168 to pad Rx6a with cable FIBRE (LoS=604.1 m)
# Connected tile Tile137 to pad Rx3a with cable FIBRE (LoS=598.5 m)
# Connected tile Tile157 to pad Rx6a with cable FIBRE (LoS=598.3 m)
# Connected tile Tile156 to pad Rx6a with cable FIBRE (LoS=591.5 m)
# Connected tile Tile158 to pad Rx6a with cable FIBRE (LoS=589.9 m)
# Connected tile Tile125 to pad Rx3a with cable FIBRE (LoS=579.0 m)
# Connected tile Tile123 to pad Rx3a with cable FIBRE (LoS=576.6 m)
# Connected tile Tile135 to pad Rx3a with cable FIBRE (LoS=573.2 m)
# Connected tile Tile155 to pad Rx6a with cable FIBRE (LoS=570.0 m)
# Connected tile Tile126 to pad Rx1 with cable FIBRE (LoS=562.9 m)
# Connected tile Tile138 to pad Rx3a with cable FIBRE (LoS=555.6 m)
# Connected tile Tile147 to pad Rx4 with cable FIBRE (LoS=551.2 m)
# Connected tile Tile134 to pad Rx4 with cable FIBRE (LoS=544.9 m)
# Connected tile Tile104 to pad Rx6a with cable FIBRE (LoS=539.1 m)
# Connected tile Tile148 to pad Rx4 with cable FIBRE (LoS=537.7 m)
# Connected tile Tile162 to pad Rx6a with cable FIBRE (LoS=534.4 m)
# Connected tile Tile154 to pad Rx4 with cable FIBRE (LoS=643.4 m)
# Connected tile Tile113 to pad Rx1 with cable FIBRE (LoS=522.1 m)
# Connected tile Tile55 to pad Rx4 with cable FIBRE (LoS=515.2 m)
# Connected tile Tile136 to pad Rx4 with cable LMR400_524 (LoS=512.9 m)
# Connected tile Tile106 to pad Rx1a with cable LMR400_524 (LoS=512.8 m)
# Connected tile Tile101 to pad Rx1a with cable LMR400_524 (LoS=507.3 m)
# Connected tile Tile115 to pad Rx1a with cable LMR400_524 (LoS=503.8 m)
# Connected tile Tile105 to pad Rx1a with cable LMR400_524 (LoS=493.2 m)
# Connected tile Tile116 to pad Rx1a with cable LMR400_524 (LoS=478.2 m)
# Connected tile Tile73 to pad Rx1a with cable LMR400_524 (LoS=470.8 m)
# Connected tile Tile122 to pad Rx4 with cable LMR400_524 (LoS=470.2 m)
# Connected tile Tile102 to pad Rx1a with cable LMR400_524 (LoS=467.7 m)
# Connected tile Tile117 to pad Rx1a with cable LMR400_524 (LoS=462.5 m)
# Connected tile Tile145 to pad Rx4 with cable LMR400_524 (LoS=453.5 m)
# Connected tile Tile103 to pad Rx2 with cable LMR400_524 (LoS=430.4 m)
# Connected tile Tile144 to pad Rx4a with cable LMR400_524 (LoS=408.0 m)
# Connected tile Tile75 to pad Rx2 with cable LMR400_524 (LoS=398.5 m)
# Connected tile Tile74 to pad Rx2 with cable LMR400_400 (LoS=376.8 m)
# Connected tile Tile54 to pad Rx4a with cable LMR400_400 (LoS=326.4 m)
# Connected tile Tile52 to pad Rx4a with cable LMR400_400 (LoS=322.0 m)
# Connected tile Tile76 to pad Rx2 with cable LMR400_400 (LoS=313.4 m)
# Connected tile Tile57 to pad Rx2 with cable LMR400_320 (LoS=302.5 m)
# Connected tile Tile56 to pad Rx4a with cable LMR400_320 (LoS=275.0 m)
# Connected tile Tile77 to pad Rx2 with cable RG6_230 (LoS=214.2 m)
# Connected tile Tile78 to pad Rx2 with cable RG6_230 (LoS=205.5 m)
# Connected tile Tile72 to pad Rx2 with cable RG6_230 (LoS=167.5 m)
# Connected tile Tile71 to pad Rx4a with cable LMR400_320 (LoS=222.1 m)
# Connected tile Tile53 to pad Rx4a with cable RG6_230 (LoS=166.6 m)
# Connected tile Tile58 to pad Rx4a with cable RG6_230 (LoS=156.5 m)
# Connected tile Tile51 to pad Rx4a with cable RG6_150 (LoS=136.7 m)
# All tiles connected
# Tile optimisation run at Wed Jun 29 16:38:35 2016
# Tiles=config-longbaseline.txt, pad configuration=pads-longbaseline.txt
#
#
# Rx1:
#   Tile108 with FIBRE (908 m LoS)
#   Tile118 with FIBRE (1094 m LoS)
#   Tile126 with FIBRE (563 m LoS)
#   Tile128 with FIBRE (1166 m LoS)
#   Tile114 with FIBRE (638 m LoS)
#   Tile107 with FIBRE (921 m LoS)
#   Tile113 with FIBRE (522 m LoS)
#   Tile112 with FIBRE (641 m LoS)
#   Max = 1165.7, Min = 522.1, difference = 643.6
#
#   LoS length totals: 0.522 km of copper, 5.931 km of fibre
#   0 existing cables re-used, plus ~6.453 km of new cable
#
# Rx1a:
#   Tile116 with LMR400_524 (478 m LoS)
#   Tile115 with LMR400_524 (504 m LoS)
#   Tile117 with LMR400_524 (462 m LoS)
#   Tile101 with LMR400_524 (507 m LoS)
#   Tile106 with LMR400_524 (513 m LoS)
#   Tile105 with LMR400_524 (493 m LoS)
#   Tile102 with LMR400_524 (468 m LoS)
#    Tile73 with LMR400_524 (471 m LoS)
#   Max = 512.8, Min = 462.5, difference = 50.3
#
#   LoS length totals: 3.896 km of copper, 0.000 km of fibre
#   0 existing cables re-used, plus ~3.896 km of new cable
#
# Rx2:
#   Tile103 with LMR400_524 (430 m LoS)
#    Tile57 with LMR400_320 (303 m LoS)
#    Tile78 with RG6_230 (205 m LoS)
#    Tile77 with RG6_230 (214 m LoS)
#    Tile76 with LMR400_400 (313 m LoS)
#    Tile75 with LMR400_524 (399 m LoS)
#    Tile74 with LMR400_400 (377 m LoS)
#    Tile72 with RG6_230 (168 m LoS)
#   Max = 430.4, Min = 167.5, difference = 262.9
#
#   LoS length totals: 2.409 km of copper, 0.000 km of fibre
#   0 existing cables re-used, plus ~2.409 km of new cable
#
# Rx3:
#   Tile133 with FIBRE (1340 m LoS)
#   Tile132 with FIBRE (1320 m LoS)
#   Tile131 with FIBRE (1119 m LoS)
#   Tile142 with FIBRE (1371 m LoS)
#   Tile141 with FIBRE (1093 m LoS)
#   LB_ESE8 with FIBRE (1942 m LoS)
#   LB_ESE1 with FIBRE (1509 m LoS)
#   LB_NNE6 with FIBRE (1665 m LoS)
#   Max = 1941.5, Min = 1092.8, difference = 848.7
#
#   LoS length totals: 0.000 km of copper, 11.358 km of fibre
#   0 existing cables re-used, plus ~11.358 km of new cable
#
# Rx3a:
#   Tile146 with FIBRE (627 m LoS)
#   Tile123 with FIBRE (577 m LoS)
#   Tile137 with FIBRE (599 m LoS)
#   Tile125 with FIBRE (579 m LoS)
#   Tile135 with FIBRE (573 m LoS)
#   Tile127 with FIBRE (712 m LoS)
#   Tile138 with FIBRE (556 m LoS)
#   Tile124 with FIBRE (620 m LoS)
#   Max = 712.1, Min = 555.6, difference = 156.6
#
#   LoS length totals: 0.000 km of copper, 4.842 km of fibre
#   0 existing cables re-used, plus ~4.842 km of new cable
#
# Rx4:
#   Tile147 with FIBRE (551 m LoS)
#   Tile122 with LMR400_524 (470 m LoS)
#   Tile145 with LMR400_524 (453 m LoS)
#   Tile136 with LMR400_524 (513 m LoS)
#   Tile134 with FIBRE (545 m LoS)
#   Tile148 with FIBRE (538 m LoS)
#    Tile55 with FIBRE (515 m LoS)
#   Tile154 with FIBRE (643 m LoS)
#   Max = 643.4, Min = 453.5, difference = 189.9
#
#   LoS length totals: 1.952 km of copper, 2.277 km of fibre
#   0 existing cables re-used, plus ~4.229 km of new cable
#
# Rx4a:
#   Tile144 with LMR400_524 (408 m LoS)
#    Tile54 with LMR400_400 (326 m LoS)
#    Tile56 with LMR400_320 (275 m LoS)
#    Tile51 with RG6_150 (137 m LoS)
#    Tile53 with RG6_230 (167 m LoS)
#    Tile52 with LMR400_400 (322 m LoS)
#    Tile58 with RG6_230 (157 m LoS)
#    Tile71 with LMR400_320 (222 m LoS)
#   Max = 408.0, Min = 136.7, difference = 271.4
#
#   LoS length totals: 2.013 km of copper, 0.000 km of fibre
#   0 existing cables re-used, plus ~2.013 km of new cable
#
# Rx5:
#   Tile151 with FIBRE (1369 m LoS)
#    LB_SE5 with FIBRE (1767 m LoS)
#    LB_SE4 with FIBRE (2446 m LoS)
#    LB_SE7 with FIBRE (2331 m LoS)
#    LB_SE6 with FIBRE (1713 m LoS)
#    LB_SE1 with FIBRE (1455 m LoS)
#    LB_SE3 with FIBRE (1755 m LoS)
#    LB_SE2 with FIBRE (2279 m LoS)
#   Max = 2446.1, Min = 1368.8, difference = 1077.3
#
#   LoS length totals: 0.000 km of copper, 15.116 km of fibre
#   0 existing cables re-used, plus ~15.116 km of new cable
#
# Rx6:
#   Tile143 with FIBRE (699 m LoS)
#   Tile161 with FIBRE (612 m LoS)
#   Tile164 with FIBRE (1089 m LoS)
#   Tile165 with FIBRE (951 m LoS)
#   Tile166 with FIBRE (648 m LoS)
#   Tile152 with FIBRE (1087 m LoS)
#   Tile153 with FIBRE (618 m LoS)
#   Tile163 with FIBRE (1007 m LoS)
#   Max = 1089.2, Min = 612.2, difference = 476.9
#
#   LoS length totals: 0.000 km of copper, 6.710 km of fibre
#   0 existing cables re-used, plus ~6.710 km of new cable
#
# Rx6a:
#   Tile104 with FIBRE (539 m LoS)
#   Tile158 with FIBRE (590 m LoS)
#   Tile168 with FIBRE (604 m LoS)
#   Tile162 with FIBRE (534 m LoS)
#   Tile167 with FIBRE (611 m LoS)
#   Tile155 with FIBRE (570 m LoS)
#   Tile157 with FIBRE (598 m LoS)
#   Tile156 with FIBRE (591 m LoS)
#   Max = 611.1, Min = 534.4, difference = 76.7
#
#   LoS length totals: 0.000 km of copper, 4.638 km of fibre
#   0 existing cables re-used, plus ~4.638 km of new cable
#
# Rx8:
#   Tile121 with FIBRE (1361 m LoS)
#     LB_N8 with FIBRE (1637 m LoS)
#     LB_N7 with FIBRE (1771 m LoS)
#   Tile111 with FIBRE (1239 m LoS)
#     LB_N3 with FIBRE (2286 m LoS)
#     LB_N1 with FIBRE (2215 m LoS)
#   LB_NNE1 with FIBRE (1272 m LoS)
#   LB_NNE7 with FIBRE (1693 m LoS)
#   Max = 2285.7, Min = 1238.6, difference = 1047.1
#
#   LoS length totals: 0.000 km of copper, 13.473 km of fibre
#   0 existing cables re-used, plus ~13.473 km of new cable
#
# Rx9:
#   LB_ESE3 with FIBRE (2347 m LoS)
#     LB_N4 with FIBRE (2518 m LoS)
#     LB_N5 with FIBRE (2040 m LoS)
#   LB_NNE8 with FIBRE (1966 m LoS)
#   LB_NNE3 with FIBRE (2455 m LoS)
#   LB_NNE2 with FIBRE (1958 m LoS)
#   LB_NNE4 with FIBRE (2397 m LoS)
#   LB_ESE7 with FIBRE (2290 m LoS)
#   Max = 2517.6, Min = 1957.7, difference = 559.9
#
#   LoS length totals: 0.000 km of copper, 17.971 km of fibre
#   0 existing cables re-used, plus ~17.971 km of new cable
#
# Rx9a:
#     LB_E8 with FIBRE (1928 m LoS)
#     LB_N6 with FIBRE (1619 m LoS)
#     LB_E1 with FIBRE (1631 m LoS)
#     LB_E7 with FIBRE (2155 m LoS)
#   LB_ESE2 with FIBRE (2175 m LoS)
#   LB_ESE5 with FIBRE (2280 m LoS)
#   LB_ESE4 with FIBRE (1861 m LoS)
#   LB_ESE6 with FIBRE (1782 m LoS)
#   Max = 2280.3, Min = 1619.0, difference = 661.3
#
#   LoS length totals: 0.000 km of copper, 15.430 km of fibre
#   0 existing cables re-used, plus ~15.430 km of new cable
#
# Rx10:
#    LB_SW7 with FIBRE (2650 m LoS)
#    LB_SW6 with FIBRE (2650 m LoS)
#    LB_SW5 with FIBRE (2650 m LoS)
#    LB_SW4 with FIBRE (2650 m LoS)
#    LB_SW3 with FIBRE (2650 m LoS)
#    LB_SW2 with FIBRE (2650 m LoS)
#    LB_SW1 with FIBRE (2650 m LoS)
#    LB_SW8 with FIBRE (2650 m LoS)
#   Max = 2650.0, Min = 2650.0, difference = 0.0
#
#   LoS length totals: 0.000 km of copper, 21.200 km of fibre
#   0 existing cables re-used, plus ~21.200 km of new cable
#
# Rx12:
#    LB_NE8 with FIBRE (2234 m LoS)
#    LB_NE4 with FIBRE (2859 m LoS)
#    LB_NE5 with FIBRE (2578 m LoS)
#    LB_NE6 with FIBRE (2301 m LoS)
#    LB_NE7 with FIBRE (2039 m LoS)
#     LB_N2 with FIBRE (1866 m LoS)
#    LB_NE2 with FIBRE (2368 m LoS)
#    LB_NE3 with FIBRE (2677 m LoS)
#   Max = 2859.1, Min = 1866.1, difference = 992.9
#
#   LoS length totals: 0.000 km of copper, 18.923 km of fibre
#   0 existing cables re-used, plus ~18.923 km of new cable
#
# Rx14:
#    LB_NE1 with FIBRE (2342 m LoS)
#     LB_E3 with FIBRE (1973 m LoS)
#     LB_E2 with FIBRE (1854 m LoS)
#     LB_E6 with FIBRE (2050 m LoS)
#     LB_E5 with FIBRE (2223 m LoS)
#     LB_E4 with FIBRE (2634 m LoS)
#   LB_NNE5 with FIBRE (1864 m LoS)
#    LB_SE8 with FIBRE (2378 m LoS)
#   Max = 2633.6, Min = 1853.6, difference = 780.0
#
#   LoS length totals: 0.000 km of copper, 17.318 km of fibre
#   0 existing cables re-used, plus ~17.318 km of new cable
#
#
# Totals for the whole array:
#    LoS lengths: 10.792 km of COPPER, 155.188 km of FIBRE
#    0 existing tile connections re-used, 165.980 km new copper
#   Cable RG6_90: 0 lengths in total, 0 of them are re-used.
#   Cable RG6_150: 1 lengths in total, 0 of them are re-used.
#   Cable RG6_230: 5 lengths in total, 0 of them are re-used.
#   Cable LMR400_320: 3 lengths in total, 0 of them are re-used.
#   Cable LMR400_400: 4 lengths in total, 0 of them are re-used.
#   Cable LMR400_524: 14 lengths in total, 0 of them are re-used.
#   Fibre: 101 lengths, with Line of Sight (LOS) distances:
#     [515.2246801483795, 522.1198880812718, 534.4478362843282, 537.6699892015547, 539.1076424926658, 544.9218439831532, 551.1742570621383, 555.5698673830323, 562.9113871765253, 569.9708801070453, 573.2164811308203, 576.6493668391565, 579.0005789081735, 589.9194335924185, 591.4753735972446, 598.3344577073929, 598.5166798519487, 604.0914686403046, 611.1445653869467, 612.2499897403021, 617.788590967007, 620.3902549347467, 626.5047324362363, 637.8258974336179, 640.7468879175302, 643.420518945425, 647.935247507033, 698.6845476329071, 712.12988617597, 907.971463497064, 921.2636493273791, 950.5400946877518, 1007.2783935387475, 1086.5124393673548, 1089.1764129524656, 1092.8449924691972, 1094.336016628348, 1118.761827647869, 1165.7492039272427, 1238.5565929419615, 1271.7488046092278, 1320.4806574929448, 1339.593932600473, 1360.5478182030206, 1368.7708864853898, 1370.691757729651, 1454.8810191386785, 1509.2671469441716, 1618.9570995335237, 1630.5931546035633, 1636.6794511219966, 1665.1399647059704, 1693.4427846635388, 1713.1927701111163, 1755.0291862763993, 1766.927213036802, 1771.3897481765553, 1781.9872667721281, 1853.591157578445, 1860.8461088467257, 1864.4479115440581, 1866.133135024401, 1927.875848260982, 1941.5268113618727, 1957.7194855456185, 1965.5402888859846, 1973.3914746458695, 2038.7347306013107, 2040.1849755728035, 2049.8921297863453, 2154.655880564226, 2175.068463888206, 2214.9534363414955, 2223.1493175916007, 2234.190454080627, 2279.4049187656415, 2280.267198597568, 2285.6844060029366, 2289.873595412856, 2301.4568783978984, 2331.3216953620968, 2341.7616456766045, 2347.463049976506, 2368.0721447540404, 2378.3993282594497, 2397.332925132636, 2446.083235421272, 2455.117702614276, 2517.569907738214, 2578.3005084910096, 2633.572482181951, 2650.0, 2650.0, 2650.0, 2650.0, 2650.0, 2650.0, 2650.0, 2650.0, 2676.829422725699, 2859.051565603006]
